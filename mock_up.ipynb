# %%
import pandas as pd
import numpy as np
import plotly.express as px

from google.colab import drive
drive.mount('/content/drive')  # mounts google drive
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
receipt = pd.read_csv("/content/drive/MyDrive/DISCUS_CF/receipt.csv") #reads the csv receipt
receipt = receipt[receipt.columns[[0,1,2,3,7,8,9]]]
receipt = receipt.dropna()

# remove £ sign
receipt.price = receipt.price.str.split('£').str.get(-1)

receipt.co2_item = pd.to_numeric(receipt.co2_item)

# %%
receipt.head()
# Out:
#    quantity   weight_unit    total_weight   ... price co2_kg  co2_item
# 0       1.0           0.37            0.37  ...  0.59   0.67      0.25
# 1       1.0           0.44            0.44  ...  0.38   0.24      0.11
# 2       1.0           0.20            0.80  ...  2.00   0.29      0.23
# 3       1.0           0.24            0.24  ...  3.25   3.80      0.91
# 4       3.0           0.22            0.66  ...  3.00   1.00      0.66
#
# [5 rows x 7 columns]

# %%
# add a classification variable to visualise high, medium or low impact
low = 3
low_std = 5

medium = 10  # these values are arbitrary, morer research needed 
medium_std = 12             # potentially these could be set by the user orrealtive to average item in the shopping/ or relative to total

receipt.loc[receipt['co2_item'] <= low, 'impact'] = 'low'
receipt.loc[receipt['co2_item'] > medium, 'impact'] = 'high'
receipt.loc[receipt['co2_item'] > low, 'impact'] = 'medium'

receipt.loc[receipt['co2_kg'] <= low, 'impact_std'] = 'low'
receipt.loc[receipt['co2_kg'] > medium, 'impact_std'] = 'high'
receipt.loc[receipt['co2_kg'] > low, 'impact_std'] = 'medium'

# %%
#  order items by impact 
  #  primarily impact by item, if items have identical impact, the one that has larger impact per kg/l will be displayed first

receipt = receipt.sort_values(by=['co2_item', 'co2_kg'], ascending=True)
receipt.head()
# Out:
#     quantity   weight_unit    total_weight   ... co2_item impact  impact_std
# 22       1.0           0.10            0.10  ...     0.03    low         low
# 42       1.0           0.08            0.08  ...     0.03    low         low
# 12       1.0           0.05            0.05  ...     0.03    low         low
# 31       1.0           0.80            0.80  ...     0.09    low         low
# 1        1.0           0.44            0.44  ...     0.11    low         low
#
# [5 rows x 9 columns]

# %%
# order items by impact per kg
receipt_std = receipt.sort_values(by=['co2_kg'], ascending=True)

receipt_std.head()
# Out:
#     quantity   weight_unit    total_weight   ... co2_item impact  impact_std
# 31       1.0           0.80            0.80  ...     0.09    low         low
# 1        1.0           0.44            0.44  ...     0.11    low         low
# 28       1.0           2.00            2.00  ...     0.49    low         low
# 2        1.0           0.20            0.80  ...     0.23    low         low
# 5        1.0           0.19            1.14  ...     0.36    low         low
#
# [5 rows x 9 columns]

# %%
fig = px.bar(receipt, 
             x='co2_item',
             y='item',
             orientation = 'h', 
             color = 'impact', 
             width=1200, height=1000,
             hover_name="item",
             hover_data = {"impact"},
             labels={ 
                  "co2_item": "co\u2082 equivalent (kg)", "item":""},
             color_discrete_map={ 
                "low": "green", "medium": "orange", "high" : "red"},
             template="simple_white")

fig.update_layout( # customize font and legend orientation & position
    showlegend = False,
    title= { "text": "My Carbon Footprint", "x" : 0.5, "xanchor": "center", "yanchor": "middle", "font" : {"size" : 25}  }
     )



fig.update_xaxes(visible = False )
fig.update_yaxes(ticks=""  )

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="
Farls x4", "Sainsbury's Zamli Dates, Taste the Difference ", "Sainsbury's Conference Pears, Ripe & Ready x4", "Doritos Lightly Salted Sharing Tortilla Chips ", "Sainsbury's Broccoli Loose", "Colman's Original English Mustard ", "Sainsbury's Walnut Cob Taste the Difference", "Kellogg's Nutri-Grain Soft & Fruity Bars, Strawberry ", "Sainsbury's Braeburn Apples x6", " Sainsbury's Taramasalata     ", "New York Bakery Co. Bagels, Plain x5", "Sainsbury's Vivaldi White Potatoes, Taste the Difference ", "Sainsbury's Plain Tortilla Wraps ", "Sainsbury's Green Pesto", "Sainsbury's Chilli Pesto ", "Sainsbury's Curly Leaf Lettuce ", "Sainsbury's Wholemeal Pittas x6", " Sainsbury's Leeks, SO Organic", "By Sainsbury?s Large Ripe & Ready Avocado", "Sainsbury's White Pittas x6", "Sainsbury's Whole Cucumber, SO Organic", "Sainsbury's Frozen All Butter Croissants x6", "Oatly Oat Drink Semi Chilled 1L", "Sainsbury's Responsibly Sourc ...
#                         {"barmode": "relative", "height": 1000, "legend": {"tracegroupgap": 0}, "margin": {"t": 60}, "showlegend": false, "template": {"data": {"bar": [{"error_x": {"color": "rgb(36,36,36)"}, "error_y": {"color": "rgb(36,36,36)"}, "marker": {"line": {"color": "white", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "white", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "rgb(36,36,36)", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "rgb(36,36,36)"}, "baxis": {"endlinecolor": "rgb(36,36,36)", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "rgb(36,36,36)"}, "type": "carpet"}], "choropleth": [{"colorbar": {"outlinewidth": 10, "tickcolor": "rgb(36,36,36)", "ticklen": 8, "ticks": "outside", "tickwidth": 2}, "type": "choropleth"}], "contour": [{"colorbar": {"outlinewidth": 10, "tickcolor": "rgb(36,36,36)", "ticklen": 8, "ticks": "outside", "tickwidth": 2}, "colorscale": [[0.0, "#440154"], [0.1111111111111111, "#482878"], [0.2222222222222222, "#3e4989"], [0.3333333333333333, "#31688e"], [0.4444444444444444, "#26828e"], [0.5555555555555556, "#1f9e89"], [0.6666666666666666, "#35b779"], [0.7777777777777778, "#6ece58"], [0.8888888888888888, "#b5de2b"], [1.0, "#fde725"]], "type": "contour"}], "contourcarpet": [{"colorbar": {"outlinewidth": 10, "tickcolor": "rgb(36,36,36)", "ticklen": 8, "ticks": "outside", "tickwidth": 2}, "type": "contourcarpet"}], "heatmap": [{"colorbar": {"outlinewidth": 10, "tickcolor": "rgb(36,36,36)", "ticklen": 8, "ticks": "outside", "tickwidth": 2}, "colorscale": [[0.0, "#440154"], [0.1111111111111111, "#482878"], [0.2222222222222222, "#3e4989"

# %%
# plot based on standardised impact ( ie. disregards weight of item)


fig_std = px.bar(receipt_std, 
             x='co2_kg',
             y='item',
             orientation = 'h', 
             color = 'impact_std', 
             width=1200, height=1000,
             hover_name="item",
             hover_data = {"impact_std"},
             labels={ 
                  "co2_item": "co\u2082 equivalent (kg)", "item":""},
             color_discrete_map={ 
                "low": "green", "medium": "orange", "high" : "red"},
             template="simple_white")

fig_std.update_layout( # customize font and legend orientation & position
    showlegend = False,
    title= { "text": "My Carbon Footprint", "x" : 0.5, "xanchor": "center", "yanchor": "middle", "font" : {"size" : 25}  }
     )



fig_std.update_xaxes(visible = False )
fig_std.update_yaxes(ticks=""  )

fig_std.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="f65928eb-d1fd-4363-9ba9-5ae73d4cba8e" class="plotly-graph-div" style="height:1000px; width:1200px;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("f65928eb-d1fd-4363-9ba9-5ae73d4cba8e")) {
#                     Plotly.newPlot(
#                         'f65928eb-d1fd-4363-9ba9-5ae73d4cba8e',
#                         [{"alignmentgroup": "True", "customdata": [["low"], ["low"], ["low"], ["low"], ["low"], ["low"], ["low"], ["low"], ["low"], ["low"], ["low"], ["low"], ["low"], ["low"], ["low"], ["low"], ["low"], ["low"], ["low"], ["low"], ["low"], ["low"], ["low"], ["low"], ["low"], ["low"], ["low"], ["low"], ["low"], ["low"], ["low"], ["low"], ["low"], ["low"], ["low"], ["low"], ["low"]], "hoverlabel": {"namelength": 0}, "hovertemplate": "<b>%{hovertext}</b><br><br>impact_std=%{customdata[0]}<br>co2_kg=%{x}<br>=%{y}", "hovertext": ["Heinz Baked Beans Snap Pots 4 Pack ", "Sainsbury's Onions Loose", "Sainsbury's Vivaldi White Potatoes, Taste the Difference ", "Sainsbury's Conference Pears, Ripe & Ready x4", "Sainsbury's Braeburn Apples x6", "Nescaf\u00e9 Azera Americano Instant Coffee ", "Sainsbury's Fresh Living Large Basil Pot", "Sainsbury's Garlic", "Sainsbury's Broccoli Loose", "Sainsbury's Walnut Cob Taste the Difference", "Sainsbury's Wholemeal Pittas x6", "Rankin Selection Potato Farls x4", "Oatly Oat Drink Semi Chilled 1L", "New York Bakery Co. Bagels, Plain x5", "Sainsbury's Plain Tortilla Wraps ", "Sainsbury's White Pittas x6", "By Sainsbury?s Large Ripe & Ready Avocado", "Doritos Lightly Salted Sharing Tortilla Chips ", "Sainsbury's Zamli Dates, Taste the Difference ", "Sainsbury's Pine Nuts ", "Sainsbury's Frozen Pain Au Chocolat x6 ", "Sainsbury's Frozen All Butter Croissants x6", " Sain
nltk.download('punkt')
from nltk.tokenize import word_tokenize
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.

# %%
# to remove stopwords

from nltk.corpus import stopwords
nltk.download('stopwords')
sr= stopwords.words('english')
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.

# %%
# for word stemming
from nltk.stem import PorterStemmer
from nltk.tokenize import sent_tokenize, word_tokenize

port_stem = PorterStemmer()

# %%
top1 = top_cf.item[0]
top2 = top_cf.item[1]
top3 = top_cf.item[2]

# %%
# word tokenize

top1= word_tokenize(top1)
top2= word_tokenize(top2)
top3= word_tokenize(top3)



# print(("Word tokenizing the text \n {}, {}, {}").format(top1, top2, top3))

# %%
# remove stop words

top1 = [w for w in top1 if not w in sr]
top2 = [w for w in top2 if not w in sr]
top3 = [w for w in top3 if not w in sr]

print(('text after removing stop words \n {},\n {},\n {}').format(top1, top2, top3))
# Out:
# text after removing stop words
#  ['Sainsbury', "'s", 'Parmigiano', 'Reggiano', 'Cheese'],
#  ['Sainsbury', "'s", 'Buffalo', 'Mozzarella', 'Cheese', ',', 'Taste', 'Difference'],
#  ['Sainsbury', "'s", 'Apple', '&', 'Mango', 'Juice', ',', 'Not', 'From', 'Concentrate']

# %%
# word stemming & word lemmatizing
top1_stem = []
top2_stem =[]
top3_stem = []
top_stems = [top1_stem, top2_stem, top3_stem] 
top_items = [top1, top2, top3]

for item in top_items:
   for word in  top_items[top_items.index(item)]:
     top_stems[top_items.index(item)].append(port_stem.stem(word))


# will get stems - useful for database retrieval? or matching?

# %%
# go through nutri csv and find an item with as many matching stems as possible
  # change path if outside google colab

nutri = pd.read_csv("/content/drive/MyDrive/DISCUS_CF/nutri_proximates.csv")
#nutri.columns
nutri = nutri [['Food Name','Group', 'Protein (g)', 'Fat (g)', 'Carbohydrate (g)', 'Energy (kcal) (kcal)' ]]

# %%
nutri = nutri.dropna()
nutri.head()
# Out:
#                          Food Name Group  ... Carbohydrate (g) Energy (kcal) (kcal)
# 2           Ackee, canned, drained    DG  ...              0.8                  151
# 3                      Agar, dried    DG  ...               Tr                   16
# 4  Agar, dried, soaked and drained    DG  ...               Tr                    2
# 5             Alfalfa sprouts, raw    DG  ...              0.4                   24
# 6                 Allspice, ground     H  ...                N                    N
#
# [5 rows x 6 columns]

# %%
# check that string contains substring
  # repeat for each element of the stemmed word
  # if true, add 1 to  a variable
  # in the end choose an item with highest value count

# %%
# for each item get protein content (standardised)
# search for item with similar protein content (or as close as possible,higher better than lower)

# %%
# dash - choose one of three visualisations
# %pip install dash
import dash
import dash_core_components as dcc
import dash_html_components as html
# Out:
# Collecting dash
#   Downloading https://files.pythonhosted.org/packages/b2/8f/4e5f73f7c1fce28c7cfb5fc7c6c5b2a2e672e5b6ac8c45100bd80a829c11/dash-1.21.0.tar.gz (1.1MB)
#      |████████████████████████████████| 1.1MB 24.9MB/s
# Requirement already satisfied: Flask>=1.0.4 in /usr/local/lib/python3.7/dist-packages (from dash) (1.1.4)
# Collecting flask-compress
#   Downloading https://files.pythonhosted.org/packages/75/fa/a3c96f3f367ad1d6532fa8394c9a6f5879513868207096f6b41f4168b342/Flask_Compress-1.10.1-py3-none-any.whl
# Requirement already satisfied: plotly in /usr/local/lib/python3.7/dist-packages (from dash) (4.4.1)
# Collecting dash-core-components==1.17.1
#   Downloading https://files.pythonhosted.org/packages/8c/1c/08770766c517305016b62ad3c455631a1b72f4f69339cb68480a32c3f1fe/dash_core_components-1.17.1.tar.gz (3.7MB)
#      |████████████████████████████████| 3.7MB 34.8MB/s
# Collecting dash-html-components==1.1.4
#   Downloading https://files.pythonhosted.org/packages/7a/92/f846276024c34a7d37a1553d1c2be8e9dfb7f13bcb47e887018571979072/dash_html_components-1.1.4.tar.gz (83kB)
#      |████████████████████████████████| 92kB 11.0MB/s
# Collecting dash-table==4.12.0
#   Downloading https://files.pythonhosted.org/packages/ab/2e/1528e0c2534e9222bf7f467efc82d86f1f2ce9ec2fa14108af357a9245b1/dash_table-4.12.0.tar.gz (1.8MB)
#      |████████████████████████████████| 1.8MB 37.4MB/s
# Requirement already satisfied: future in /usr/local/lib/python3.7/dist-packages (from dash) (0.16.0)
# Requirement already satisfied: itsdangerous<2.0,>=0.24 in /usr/local/lib/python3.7/dist-packages (from Flask>=1.0.4->dash) (1.1.0)
# Requirement already satisfied: Jinja2<3.0,>=2.10.1 in /usr/local/lib/python3.7/dist-packages (from Flask>=1.0.4->dash) (2.11.3)
# Requirement already satisfied: click<8.0,>=5.1 in /usr/local/lib/python3.7/dist-packages (from Flask>=1.0.4->dash) (7.1.2)
# Requirement already satisfied: Werkzeug<2.0,>=0.15 in /usr/local/lib/python3.7/dist-packages (from Flask>=1.0.4->dash) (1.0.1)
# Collecting brotli
#   Downloading https://files.pythonhosted.org/packages/15/ea/5bd575511b37bbd1c794606a0a621e6feff8e96b7dd007a86a5d218b2d94/Brotli-1.0.9-cp37-cp37m-manylinux1_x86_64.whl (357kB)
#      |████████████████████████████████| 358kB 42.4MB/s
# Requirement already satisfied: six in /usr/local/lib/python3.7/dist-packages (from plotly->dash) (1.15.0)
# Requirement already satisfied: retrying>=1.3.3 in /usr/local/lib/python3.7/dist-packages (from plotly->dash) (1.3.3)
# Requirement already satisfied: MarkupSafe>=0.23 in /usr/local/lib/python3.7/dist-packages (from Jinja2<3.0,>=2.10.1->Flask>=1.0.4->dash) (2.0.1)
# Building wheels for collected packages: dash, dash-core-components, dash-html-components, dash-table
#   Building wheel for dash (setup.py) ... done
#   Created wheel for dash: filename=dash-1.21.0-cp37-none-any.whl size=1100490 sha256=a542938de12020562d6ff9cb91ceecc7dbfa669f0361c7ed48013ffba4d765cb
#   Stored in directory: /root/.cache/pip/wheels/7f/d6/e7/f0377e473d9b294478da4d5440e02b4bf864c2a8d6150b3990
#   Building wheel for dash-core-components (setup.py) ... done
#   Created wheel for dash-core-components: filename=dash_core_components-1.17.1-cp37-none-any.whl size=3738997 sha256=5129c1821bdfe5897d9a1c7f32b943d61c3c3b656fc5facaa3185778c56ce7b1
#   Stored in directory: /root/.cache/pip/wheels/da/56/29/0e0b53d70c9f15f55c882dc2fa9778ed2549c48493b39b1106
#   Building wheel for dash-html-components (setup.py) ... done
#   Created wheel for dash-html-components: filename=dash_html_components-1.1.4-cp37-none-any.whl size=319773 sha256=ee79fe6e8391fcc1ed15acf3efb0396fd2c2f722a765c0c748c84b7639db09fc
#   Stored in directory: /root/.cache/pip/wheels/cd/c0/f1/e953b1feaf6d0f3cd2ebed89a2e7d5be019bb596e2313ba2c1
#   Building wheel for dash-table (setup.py) ... done
#   Created wheel for dash-table: filename=dash_table-4.12.0-cp37-none-any.whl size=1837678 sha256=b4105b586a317d3f3eddf7f030d0a9e7ed63021528737c58686b69d521a76d47
#   Stored in directory: /root/.cache/pip/wheels/8d/46/ea/134906ad3417f32c4c14b08abc7f1790beee74bfa5671fa85b
# Successfully built dash dash-core-components dash-html-components dash-table
# Installing collected packages: brotli, flask-compress, dash-core-components, dash-html-components, dash-table, dash
# Successfully installed brotli-1.0.9 dash-1.21.0 dash-core-components-1.17.1 dash-html-components-1.1.4 dash-table-4.12.0 flask-compress-1.10.1

# %%
app = dash.Dash(__name__)



app.layout = html.Div(style = {
  'backgroundColor': '#a6bd2e'
}, children = [
    html.H1(
    children = 'My carbon footprint',
    style = {
      'textAlign': 'center',
      'color': '#7FDBFF'
    }
  ),

    html.Div(children = ' interactive data visualization.', style = {
    'textAlign': 'center',
    'color': '#7FDBFF'
  }),

    dcc.Graph(
    id = 'carbon footprint',
    figure = fig
  )
])

if __name__ == '__main__':
  app.run_server(debug = True)
